# %% [markdown]
# # Tutorial Basics Noten Part 1: Einführung und Visualisierung

# %% [markdown]
# Inhaltsverzeichnis:
# 1. Jupyter-Notebook: Grundlegende Funktionen
# 2. Laden von Dateien
# 3. Der xml-Parser
# 4. Pianorollendarstellung
# 5. Auswahl von Stimmen bzw. Takten
# 6. Vertiefung

# %% [markdown]
# Dieses  einführende Tutorial zeigt Ihnen den Aufbau und die Funktionsweise eines Jupyter-Notebooks und wie Sie die Jupyter-Notebooks für die Analyse von Notendaten nutzen können.
#
# Auf dieser Grundlage zeigt Ihnen das Tutorial Part 2 Möglichkeiten einfacher statistischer Abfragen.

# %% [markdown]
# ### 1. Jupyter-Notebook: Grundlegende Funktionen

# %% [markdown]
# Ein Jupyter-Notebook ist eine Datei, die im Browser geöffnet und bearbeitet werden kann. Jedes Jupyter-Notebook besteht aus einer Folge von Textblöcken (Markdown cells) und Blöcken mit Python-Colde (Code cells). Beide Blöcke können von jedem User verändert und bearbeitet werden, indem innerhalb eines Blocks die Eingabetaste gedrückt wird.
# Eigene, veränderte Versionen des Notebooks können unter neuem Namen abgespeichert werden (Menu: File -> Save as...).
#
# WICHTIG: Die Befehle jeder einzelnen Code cell werden mit dem Run-Button ausgeführt. Während der Ausführung (die bei manchen Befehlen einige Sekunden dauern kann) wird oben auf dem Tab ein Sanduhr-Symbol angezeigt. Anschließend werden ggf. Ergebnisse (oder Fehlermeldungen) angezeigt und der Cursor springt zur nächsten Box.
# Gehen Sie in den Tutorials jeweils Code cell für Code cell durch, aktivieren Sie den Code mit dem Run-Button und warten Sie ab, was geschieht!
#
# In den Code Cells werden alle Zeilen hinter einem Rautezeicheen (#) nicht ausgeführt; dies bietet die Möglichkeit, entweder Erläuterungen zum Code in den Code cells zu vermerken oder zusätzliche deaktivierte Befehle zu vermerken, die durch Löschen der Raute (und anschließendem Run) ausgeführt werden.

# %%
# Mit den Befehlen können Sie selbstverständlich auch rechnen. 
 
21 * 7 + 1 
# Drücken Sie bitte dann auf 'Run'!

# Verändern Sie z.B. den folgenden Rechenbefehl:
# Drücken Sie bitte dann auf 'Run'!
# Out:
# 148

# %% [markdown]
# Eine neue Cell wird mit dem +-Button oder den Menu-Punkt Insert erzeugt und kann dann im Menu als Markdown oder Code cell festgelegt werden. Hier können Sie Ihre eigenen Kommentare oder Befehle vermerken. (Und bitte nicht vergessen, das Notebook zuvor unter neuem Namen abzuspeichern!).
#
# Parallel zum Notebook läuft ein Command-Fenster ("Anaconda Prompt"), das Sie nicht weiter beachten müssen - das Sie aber bitte auch nicht schließen! Beenden Sie ein Notebook bitte mit dem Menu-Befehl "File" -> "Close and Halt", loggen Sie sich dann aus und schließen Sie erst zum Schluss das Command-Fenster.

# %% [markdown]
# Jeder Start eines Jupyter Notebooks beginnt mit dem Import einer Reihe von Python-Bibliotheken, die für die Analyse erforderlich sind:

# %%
import sys
import os
sys.path.append(os.getcwd().replace(os.path.join('music_xml_parser', 'ipynb'), ''))


import music_xml_parser as mp
from music21 import * 
import csv
from IPython.display import HTML, display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Mit diesen Befehlen wird der Kern von CAMAT, der 'music_xml_parser', 
# aber u.a. auch die python-Bibliotheken 'numpy' und 'pandas' für statische Auswertungen, 
# 'matplotlib' für grafische Darstellungen, 
# 'csv' für den Tabellenexport geladen 
# sowie 'music21' geladen.

# Mit den folgenden Befehlen wird die Formatierung für die Tabellen festgelegt, 
# die weiter unten dargestellt werden: 

pd.set_option('display.max_rows', 9999)
pd.set_option('display.max_columns', 9999)
pd.set_option('display.width', 9999)

# Durch den folgenden Befehl wird der Download von URLs aus dem Internet erlaubt: 
environment.set('autoDownload', 'allow')

# %% [markdown]
# ### 2. Laden von Notendateien

# %% [markdown]
# Als nächstes wird eine Notendatei im xml-Format geladen und mit dem Namen 'xml_file' versehen. Dabei gibt es zwei Möglichkeiten:
# 1. Eine Notendatei wird von der lokalen Festplatte geladen, der zuvor in den Ordner 'data' des 'music_xml_parser' gelegt wurde. Dann muss der Dateiname kopiert werden (in einfache Anführungszeichen).
# 2. Eine Notendatei wird direkt aus dem Internet geladen, indem der URL kopiert wird (in einfache Anführungszeichen):

# %%
xml_file = 'PrJode_Jos1102_COM_1-5_MissaLasol_002_00137.xml'
#xml_file = 'BaJoSe_BWV18_COM_5-5_CantataGle_004_00110.xml'
# xml_file = 'BeLuva_Op59_1-3_1-4_StringQuar_003_00129.xml'
#xml_file = 'PrJode_Jos1102_COM_1-5_MissaLasol_002_00137.xml'
#xml_file = 'BaJoSe_BWV18_COM_5-5_CantataGle_004_00110.xml'
# xml_file = 'BeLuva_Op59_1-3_1-4_StringQuar_003_00129.xml'

#xml_file = 'MoWo_K279_COM_1-3_PianoSonat_003_00920.xml'
# xml_file = 'https://analyse.hfm-weimar.de/database/03/BoMaEn_Op115_11-22_COM_ThemeetVar_003_00181.xml'
# xml_file = 'https://analyse.hfm-weimar.de/database/03/MoWo_K279_COM_1-3_PianoSonat_003_00920.xml'
#xml_file = 'https://analyse.hfm-weimar.de/database/04/BaJoSe_BWV7_COM_2-7_CantataChr_004_00038.xml'

#xml_file = 'MoWo_K279_COM_1-3_PianoSonat_003_00920.xml'
# xml_file = 'https://analyse.hfm-weimar.de/database/03/BoMaEn_Op115_11-22_COM_ThemeetVar_003_00181.xml'
# xml_file = 'https://analyse.hfm-weimar.de/database/03/MoWo_K279_COM_1-3_PianoSonat_003_00920.xml'
#xml_file = 'https://analyse.hfm-weimar.de/database/04/BaJoSe_BWV7_COM_2-7_CantataChr_004_00038.xml'
# xml_file = 'https://analyse.hfm-weimar.de/database/03/MoWo_K171_COM_1-4_StringQuar_003_00867.xml'

# %% [markdown]
# ### 3. Der xml-Parser

# %% [markdown]
# Der **xml-Parser** ist ein Python-Modul für die Verarbeitung der MusicXML-Files mit diversen Features, u.a. für den Export und Visualizierung verschiedener statistischer Informationen. Das Grundkonzept des Moduls besteht in der Speicherung der gesamten in der Notendatei vorhandenen Informationen in Form eines [Pandas-Dataframes](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#dataframe), welches sehr effiziente Kalkulationen und Datenverwaltung der geparsten Daten ermöglicht.
#
# **Parser** verfügt über eine intern festgelegte Datenstruktur, die sich bei der Exktraktion der zip-Datei bereits auf Ihrem Rechner wiederfindet (Ordner *music_xml_parser*). Darin gibt es drei Ordner:
#
# 1. **core** enthält alle programmrelevanten Python-Scripte. //Bitte nicht verändern!!//
#
# 2. **data** enthält die Ordner
# - **xmls_to_parse**. Darin liegen alle xml-Files, die beim Laden direkt (also ohne weitere Pfadangabe) eingelesen werden können. Sie können selbst xml-Dateien in den Ordner legen, oder aber Dateien direkt aus dem Internet einlesen.
# - **exports**: Hier liegen alle Dateien, die Sie im Laufe Ihrer Arbeit mit dem Jupyter-Notebooks selbst generiert haben, z.B. Tabellen (.csv) oder Grafiken (.png).
#
# 3. **ipynb** - enthält alle Jupyter-Notebooks (.ipynb); modifizierte Notebooks sollten ebenfalls hier gespeichert werden.

# %% [markdown]
# @ Christon: export files seems to be saved not in the *export*-folder but in the *ipynb*-Folder. Please fix the bug!

# %% [markdown]
# Durch den folgenden Befehl wird aus der Notendatei ('xml_file', s. oben) der Pandas-Dataframe mit der Bezeichnung 'm_df' generiert.
#
# Durch den Befehl 'm_df' werden die Daten als Tabelle im Browser dargestellt.
#
# ACHTUNG: Bei großen Notendateien benötigt diese Darstellung viel Speicherplatz; der Befehl sollte dann übersprungen werden.

# %%
m_df = mp.parse.with_xml_file(file=xml_file,
                              save_file_name=None,
                              do_save=True)

# save_file_name == None then same xml filename is used .csv
# do_save will save as .csv in exports
# Out:
# /Users/chris/DocumentLocal/workspace/hfm/scripts_in_progress/xml_parser/music_xml_parser/core/xml_parser.py:884: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 0 in meau or '0' in meau:

# %%
m_df
# Out:
#      #Note_Debug  Onset  Duration Pitch Octave  MIDI  Measure  Voice  PartID  PartName  MeasureOnset  MeasureOnset_ref TimeSignature TimeSignatureAdjusted Upbeat UpbeatMeasure ChordTag TieType GraceTag
# 0              1    0.0       8.0     A      4  69.0        1      0       1  Superius           0.0               0.0           3/1                  12/4   none          none     none    none     none
# 1              2    8.0       4.0     G      4  67.0        1      0       1  Superius           0.0               0.0           3/1                  12/4   none          none     none    none     none
# 2              3   12.0       8.0     F      4  65.0        2      0       1  Superius          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 3              4   20.0       4.0     D      4  62.0        2      0       1  Superius          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 4              5   24.0       4.0     E      4  64.0        3      0       1  Superius          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 5              6   28.0       4.0     A      4  69.0        3      0       1  Superius          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 6              7   32.0       4.0     G      4  67.0        3      0       1  Superius          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 7              8   36.0       8.0     F      4  65.0        4      0       1  Superius          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 8              9   44.0       4.0     D      4  62.0        4      0       1  Superius          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 9             10   48.0       2.0     E      4  64.0        5      0       1  Superius          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 10            11   50.0       3.0     G      4  67.0        5      0       1  Superius          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 11            12   53.0       1.0     F      4  65.0        5      0       1  Superius          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 12            13   54.0       2.0     G      4  67.0        5      0       1  Superius          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 13            14   56.0       2.0     A      4  69.0        5      0       1  Superius          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 14            15   58.0       2.0     B      4  71.0        5      0       1  Superius          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 15            16   60.0       3.0     C      5  72.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 16            17   63.0       1.0     B      4  71.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 17            18   64.0       2.0     G      4  67.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 18            19   66.0       3.0     A      4  69.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 19            20   69.0       1.0     G      4  67.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 20            21   70.0       1.0     F      4  65.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 21            22   71.0       1.0     E      4  64.0        6      0       1  Superius          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 22            23   72.0       2.0     D      4  62.0        7      0       1  Superius          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 23            24   74.0       3.0     G      4  67.0        7      0       1  Superius          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 24            25   77.0       1.0     C      4  60.0        7      0       1  Superius          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 25            26   78.0       2.0     C      4  60.0        7      0       1  Superius          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 26            27   80.0       2.0     D      4  62.0        7      0       1  Superius          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 27            28   82.0       2.0     F      4  65.0        7      0       1  Superius          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 28            29   84.0       3.0     E      4  64.0        8      0       1  Superius          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 29            30   87.0       1.0     A      3  57.0        8      0       1  Superius          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 30            31   88.0       2.0     A      3  57.0        8      0       1  Superius          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 31            32   90.0       4.0     A      4  69.0        8      0       1  Superius          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 32            33   94.0       2.0    G1      4  68.0        8      0       1  Superius          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 33            34   96.0       8.0     A      4  69.0        9      0       1  Superius          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 34            35  104.0       4.0  rest   rest   NaN        9      0       1  Superius          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 35            36  108.0       8.0     A      4  69.0       10      0       1  Superius         108.0             108.0           3/1                  12/4   none          none     none    none     none
# 36            37  116.0       4.0     A      4  69.0       10      0       1  Superius         108.0             108.0           3/1                  12/4   none          none     none    none     none
# 37            38  120.0       4.0     G      4  67.0       11      0       1  Superius         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 38            39  124.0       4.0     C      5  72.0       11      0       1  Superius         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 39            40  128.0       4.0     B      4  71.0       11      0       1  Superius         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 40            41  132.0      12.0     A      4  69.0       12      0       1  Superius         132.0             132.0           3/1                  12/4   none          none     none    none     none
# 41            42  144.0      12.0     G      4  67.0       13      0       1  Superius         144.0             144.0           3/1                  12/4   none          none     none    none     none
# 42            43  156.0       8.0     A      4  69.0       14      0       1  Superius         156.0             156.0           2/1                   8/4   none          none     none    none     none
# 43            44  164.0       8.0     G      4  67.0       15      0       1  Superius         164.0             164.0           2/1                   8/4   none          none     none    none     none
# 44            45  172.0       4.0     F      4  65.0       16      0       1  Superius         172.0             172.0           2/1                   8/4   none          none     none    none     none
# 45            46  176.0       4.0     D      4  62.0       16      0       1  Superius         172.0             172.0           2/1                   8/4   none          none     none    none     none
# 46            47  180.0       4.0     E      4  64.0       17      0       1  Superius         180.0             180.0           2/1                   8/4   none          none     none    none     none
# 47            48  184.0       6.0     A      4  69.0       17      0       1  Superius         180.0             180.0           2/1                   8/4   none          none     none   start     none
# 48            50  190.0       2.0     G      4  67.0       18      0       1  Superius         188.0             188.0           2/1                   8/4   none          none     none    none     none
# 49            51  192.0       4.0     G      4  67.0       18      0       1  Superius         188.0             188.0           2/1                   8/4   none          none     none    none     none
# 50            52  196.0       4.0     F      4  65.0       19      0       1  Superius         196.0             196.0           2/1                   8/4   none          none     none    none     none
# 51            53  200.0       4.0     D      4  62.0       19      0       1  Superius         196.0             196.0           2/1                   8/4   none          none     none    none     none
# 52            54  204.0      16.0     E      4  64.0       20      0       1  Superius         204.0             204.0           2/1                   8/4   none          none     none   start     none
# 53            56  220.0       8.0  rest   rest   NaN       22      0       1  Superius         220.0             220.0           2/1                   8/4   none          none     none    none     none
# 54            57  228.0       8.0  rest   rest   NaN       23      0       1  Superius         228.0             228.0           2/1                   8/4   none          none     none    none     none
# 55            58  236.0       8.0  rest   rest   NaN       24      0       1  Superius         236.0             236.0           2/1                   8/4   none          none     none    none     none
# 56            59  244.0       8.0  rest   rest   NaN       25      0       1  Superius         244.0             244.0           2/1                   8/4   none          none     none    none     none
# 57            60  252.0       8.0  rest   rest   NaN       26      0       1  Superius         252.0             252.0           2/1                   8/4   none          none     none    none     none
# 58            61  260.0       4.0  rest   rest   NaN       27      0       1  Superius         260.0             260.0           2/1                   8/4   none          none     none    none     none
# 59            62  264.0       4.0     B      4  71.0       27      0       1  Superius         260.0             260.0           2/1                   8/4   none          none     none    none     none
# 60            63  268.0       6.0     C      5  72.0       28      0       1  Superius         268.0             268.0           2/1                   8/4   none          none     none    none     none
# 61            64  274.0       1.0     B      4  71.0       28      0       1  Superius         268.0             268.0           2/1                   8/4   none          none     none    none     none
# 62            65  275.0       1.0     A      4  69.0       28      0       1  Superius         268.0             268.0           2/1                   8/4   none          none     none    none     none
# 63            66  276.0       4.0     C      5  72.0       29      0       1  Superius         276.0             276.0           2/1                   8/4   none          none     none    none     none
# 64            67  280.0       4.0     B      4  71.0       29      0       1  Superius         276.0             276.0           2/1                   8/4   none          none     none    none     none
# 65            68  284.0       8.0     A      4  69.0       30      0       1  Superius         284.0             284.0           2/1                   8/4   none          none     none    none     none
# 66            69  292.0       4.0     G      4  67.0       31      0       1  Superius         292.0             292.0           2/1                   8/4   none          none     none    none     none
# 67            70  296.0       8.0     C      5  72.0       31      0       1  Superius         292.0             292.0           2/1                   8/4   none          none     none   start     none
# 68            72  304.0       4.0     B      4  71.0       32      0       1  Superius         300.0             300.0           2/1                   8/4   none          none     none    none     none
# 69            73  308.0       2.0     A      4  69.0       33      0       1  Superius         308.0             308.0           2/1                   8/4   none          none     none    none     none
# 70            74  310.0       2.0     C      5  72.0       33      0       1  Superius         308.0             308.0           2/1                   8/4   none          none     none    none     none
# 71            75  312.0       2.0     B      4  71.0       33      0       1  Superius         308.0             308.0           2/1                   8/4   none          none     none    none     none
# 72            76  314.0       4.0     A      4  69.0       33      0       1  Superius         308.0             308.0           2/1                   8/4   none          none     none   start     none
# 73            78  318.0       1.0    G1      4  68.0       34      0       1  Superius         316.0             316.0           2/1                   8/4   none          none     none    none     none
# 74            79  319.0       1.0    F1      4  66.0       34      0       1  Superius         316.0             316.0           2/1                   8/4   none          none     none    none     none
# 75            80  320.0       4.0    G1      4  68.0       34      0       1  Superius         316.0             316.0           2/1                   8/4   none          none     none    none     none
# 76            81  324.0      16.0     A      4  69.0       35      0       1  Superius         324.0             324.0           2/1                   8/4   none          none     none   start     none
# 77            83  340.0       4.0     D      4  62.0       37      0       1  Superius         340.0             340.0           2/1                   8/4   none          none     none    none     none
# 78            84  344.0       4.0     D      5  74.0       37      0       1  Superius         340.0             340.0           2/1                   8/4   none          none     none    none     none
# 79            85  348.0       4.0     C      5  72.0       38      0       1  Superius         348.0             348.0           2/1                   8/4   none          none     none    none     none
# 80            86  352.0       6.0     A      4  69.0       38      0       1  Superius         348.0             348.0           2/1                   8/4   none          none     none   start     none
# 81            88  358.0       2.0     B      4  71.0       39      0       1  Superius         356.0             356.0           2/1                   8/4   none          none     none    none     none
# 82            89  360.0       4.0     C      5  72.0       39      0       1  Superius         356.0             356.0           2/1                   8/4   none          none     none    none     none
# 83            90  364.0       8.0     D      5  74.0       40      0       1  Superius         364.0             364.0           2/1                   8/4   none          none     none    none     none
# 84            91  372.0       8.0     C      5  72.0       41      0       1  Superius         372.0             372.0           2/1                   8/4   none          none     none    none     none
# 85            92  380.0       4.0     A      4  69.0       42      0       1  Superius         380.0             380.0           3/1                  12/4   none          none     none    none     none
# 86            93  384.0       2.0     G      4  67.0       42      0       1  Superius         380.0             380.0           3/1                  12/4   none          none     none    none     none
# 87            94  386.0       4.0     F      4  65.0       42      0       1  Superius         380.0             380.0           3/1                  12/4   none          none     none    none     none
# 88            95  390.0       2.0     D      4  62.0       42      0       1  Superius         380.0             380.0           3/1                  12/4   none          none     none    none     none
# 89            96  392.0       2.0     E      4  64.0       43      0       1  Superius         392.0             392.0           3/1                  12/4   none          none     none    none     none
# 90            97  394.0       2.0     A      4  69.0       43      0       1  Superius         392.0             392.0           3/1                  12/4   none          none     none    none     none
# 91            98  396.0       2.0     G      4  67.0       43      0       1  Superius         392.0             392.0           3/1                  12/4   none          none     none    none     none
# 92            99  398.0       4.0     F      4  65.0       43      0       1  Superius         392.0             392.0           3/1                  12/4   none          none     none    none     none
# 93           100  402.0       2.0     D      4  62.0       43      0       1  Superius         392.0             392.0           3/1                  12/4   none          none     none    none     none
# 94           101  404.0       2.0     E      4  64.0       44      0       1  Superius         404.0             404.0           3/1                  12/4   none          none     none    none     none
# 95           102  406.0       2.0     A      4  69.0       44      0       1  Superius         404.0             404.0           3/1                  12/4   none          none     none    none     none
# 96           103  408.0       2.0     G      4  67.0       44      0       1  Superius         404.0             404.0           3/1                  12/4   none          none     none    none     none
# 97           104  410.0       2.0     F      4  65.0       44      0       1  Superius         404.0             404.0           3/1                  12/4   none          none     none    none     none
# 98           105  412.0       4.0     D      4  62.0       44      0       1  Superius         404.0             404.0           3/1                  12/4   none          none     none    none     none
# 99           106  416.0       4.0     E      4  64.0       45      0       1  Superius         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 100          107  420.0       4.0  rest   rest   NaN       45      0       1  Superius         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 101          108  424.0       4.0     A      4  69.0       45      0       1  Superius         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 102          109  428.0       2.0     G      4  67.0       46      0       1  Superius         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 103          110  430.0       2.0     C      5  72.0       46      0       1  Superius         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 104          111  432.0       2.0     B      4  71.0       46      0       1  Superius         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 105          112  434.0       4.0     A      4  69.0       46      0       1  Superius         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 106          113  438.0       1.0     G      4  67.0       46      0       1  Superius         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 107          114  439.0       1.0     F      4  65.0       46      0       1  Superius         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 108          115  440.0       2.0     G      4  67.0       47      0       1  Superius         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 109          116  442.0       2.0     E      4  64.0       47      0       1  Superius         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 110          117  444.0       2.0     G      4  67.0       47      0       1  Superius         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 111          118  446.0       2.0     A      4  69.0       47      0       1  Superius         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 112          119  448.0       4.0     F      4  65.0       47      0       1  Superius         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 113          120  452.0       1.0     E      4  64.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 114          121  453.0       1.0     F      4  65.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 115          122  454.0       1.0     G      4  67.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 116          123  455.0       1.0     A      4  69.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 117          124  456.0       2.0     B      4  71.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 118          125  458.0       2.0     C      5  72.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 119          126  460.0       2.0     A      4  69.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 120          127  462.0       2.0     C      5  72.0       48      0       1  Superius         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 121          128  464.0       4.0     B      4  71.0       49      0       1  Superius         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 122          129  468.0       4.0  rest   rest   NaN       49      0       1  Superius         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 123          130  472.0       4.0     C      5  72.0       49      0       1  Superius         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 124          131  476.0       3.0     B      4  71.0       50      0       1  Superius         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 125          132  479.0       1.0     A      4  69.0       50      0       1  Superius         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 126          133  480.0       2.0     B      4  71.0       50      0       1  Superius         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 127          134  482.0       4.0     C      5  72.0       50      0       1  Superius         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 128          135  486.0       1.0     B      4  71.0       50      0       1  Superius         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 129          136  487.0       1.0     A      4  69.0       50      0       1  Superius         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 130          137  488.0       2.0     G      4  67.0       51      0       1  Superius         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 131          138  490.0       2.0     C      5  72.0       51      0       1  Superius         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 132          139  492.0       2.0     B      4  71.0       51      0       1  Superius         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 133          140  494.0       4.0     A      4  69.0       51      0       1  Superius         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 134          141  498.0       2.0    G1      4  68.0       51      0       1  Superius         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 135          142  500.0       2.0     A      4  69.0       52      0       1  Superius         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 136          143  502.0       2.0     C      5  72.0       52      0       1  Superius         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 137          144  504.0       2.0     B      4  71.0       52      0       1  Superius         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 138          145  506.0       3.0     A      4  69.0       52      0       1  Superius         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 139          146  509.0       1.0     G      4  67.0       52      0       1  Superius         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 140          147  510.0       2.0     F      4  65.0       52      0       1  Superius         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 141          148  512.0       4.0     E      4  64.0       53      0       1  Superius         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 142          149  516.0       4.0  rest   rest   NaN       53      0       1  Superius         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 143          150  520.0       4.0     F      4  65.0       53      0       1  Superius         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 144          151  524.0       3.0     E      4  64.0       54      0       1  Superius         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 145          152  527.0       1.0     D      4  62.0       54      0       1  Superius         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 146          153  528.0       2.0     E      4  64.0       54      0       1  Superius         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 147          154  530.0       4.0     F      4  65.0       54      0       1  Superius         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 148          155  534.0       1.0     E      4  64.0       54      0       1  Superius         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 149          156  535.0       1.0     D      4  62.0       54      0       1  Superius         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 150          157  536.0       4.0     C      4  60.0       55      0       1  Superius         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 151          158  540.0       2.0     B      3  59.0       55      0       1  Superius         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 152          159  542.0       2.0     A      3  57.0       55      0       1  Superius         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 153          160  544.0       3.0     C      4  60.0       55      0       1  Superius         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 154          161  547.0       1.0     D      4  62.0       55      0       1  Superius         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 155          162  548.0       1.0     E      4  64.0       56      0       1  Superius         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 156          163  549.0       1.0     F      4  65.0       56      0       1  Superius         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 157          164  550.0       4.0     G      4  67.0       56      0       1  Superius         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 158          165  554.0       2.0     E      4  64.0       56      0       1  Superius         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 159          166  556.0       2.0     F      4  65.0       56      0       1  Superius         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 160          167  558.0       3.0     E      4  64.0       56      0       1  Superius         548.0             548.0           3/1                  12/4   none          none     none   start     none
# 161          169  561.0       1.0     D      4  62.0       57      0       1  Superius         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 162          170  562.0       3.0     G      4  67.0       57      0       1  Superius         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 163          171  565.0       1.0     F      4  65.0       57      0       1  Superius         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 164          172  566.0       4.0     E      4  64.0       57      0       1  Superius         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 165          173  570.0       2.0     D      4  62.0       57      0       1  Superius         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 166          174  572.0      12.0     E      4  64.0       58      0       1  Superius         572.0             572.0           3/1                  12/4   none          none     none    none     none
# 167          175    0.0       8.0     A      3  57.0        1      0       2     Altus           0.0               0.0           3/1                  12/4   none          none     none    none     none
# 168          176    8.0       2.0     B      3  59.0        1      0       2     Altus           0.0               0.0           3/1                  12/4   none          none     none    none     none
# 169          177   10.0       2.0     C      4  60.0        1      0       2     Altus           0.0               0.0           3/1                  12/4   none          none     none    none     none
# 170          178   12.0       4.0     D      4  62.0        2      0       2     Altus          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 171          179   16.0       2.0  rest   rest   NaN        2      0       2     Altus          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 172          180   18.0       2.0     A      3  57.0        2      0       2     Altus          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 173          181   20.0       2.0     B      3  59.0        2      0       2     Altus          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 174          182   22.0       2.0     D      4  62.0        2      0       2     Altus          12.0              12.0           3/1                  12/4   none          none     none    none     none
# 175          183   24.0       2.0     C      4  60.0        3      0       2     Altus          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 176          184   26.0       4.0     A      3  57.0        3      0       2     Altus          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 177          185   30.0       1.0     G      3  55.0        3      0       2     Altus          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 178          186   31.0       1.0     F      3  53.0        3      0       2     Altus          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 179          187   32.0       4.0     E      3  52.0        3      0       2     Altus          24.0              24.0           3/1                  12/4   none          none     none    none     none
# 180          188   36.0       2.0     D      3  50.0        4      0       2     Altus          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 181          189   38.0       3.0     D      4  62.0        4      0       2     Altus          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 182          190   41.0       1.0     E      4  64.0        4      0       2     Altus          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 183          191   42.0       4.0     F      4  65.0        4      0       2     Altus          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 184          192   46.0       1.0     E      4  64.0        4      0       2     Altus          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 185          193   47.0       1.0     D      4  62.0        4      0       2     Altus          36.0              36.0           3/1                  12/4   none          none     none    none     none
# 186          194   48.0       4.0     C      4  60.0        5      0       2     Altus          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 187          195   52.0       2.0  rest   rest   NaN        5      0       2     Altus          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 188          196   54.0       2.0     C      3  48.0        5      0       2     Altus          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 189          197   56.0       2.0     F      3  53.0        5      0       2     Altus          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 190          198   58.0       2.0     G      3  55.0        5      0       2     Altus          48.0              48.0           3/1                  12/4   none          none     none    none     none
# 191          199   60.0       3.0     A      3  57.0        6      0       2     Altus          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 192          200   63.0       1.0     G      3  55.0        6      0       2     Altus          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 193          201   64.0       2.0     E      3  52.0        6      0       2     Altus          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 194          202   66.0       4.0     F      3  53.0        6      0       2     Altus          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 195          203   70.0       2.0     D      3  50.0        6      0       2     Altus          60.0              60.0           3/1                  12/4   none          none     none    none     none
# 196          204   72.0       3.0     G      3  55.0        7      0       2     Altus          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 197          205   75.0       1.0     E      3  52.0        7      0       2     Altus          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 198          206   76.0       2.0     E      3  52.0        7      0       2     Altus          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 199          207   78.0       2.0     A      3  57.0        7      0       2     Altus          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 200          208   80.0       2.0  rest   rest   NaN        7      0       2     Altus          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 201          209   82.0       2.0     D      3  50.0        7      0       2     Altus          72.0              72.0           3/1                  12/4   none          none     none    none     none
# 202          210   84.0       6.0     A      3  57.0        8      0       2     Altus          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 203          211   90.0       2.0     F      3  53.0        8      0       2     Altus          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 204          212   92.0       4.0     E      3  52.0        8      0       2     Altus          84.0              84.0           3/1                  12/4   none          none     none    none     none
# 205          213   96.0       3.0     E      4  64.0        9      0       2     Altus          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 206          214   99.0       1.0     D      4  62.0        9      0       2     Altus          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 207          215  100.0       2.0     C      4  60.0        9      0       2     Altus          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 208          216  102.0       2.0     A      3  57.0        9      0       2     Altus          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 209          217  104.0       4.0     B      3  59.0        9      0       2     Altus          96.0              96.0           3/1                  12/4   none          none     none    none     none
# 210          218  108.0       2.0  rest   rest   NaN       10      0       2     Altus         108.0             108.0           3/1                  12/4   none          none     none    none     none
# 211          219  110.0       6.0     A      3  57.0       10      0       2     Altus         108.0             108.0           3/1                  12/4   none          none     none    none     none
# 212          220  116.0       4.0     D      4  62.0       10      0       2     Altus         108.0             108.0           3/1                  12/4   none          none     none    none     none
# 213          221  120.0       2.0     B      3  59.0       11      0       2     Altus         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 214          222  122.0       4.0     E      4  64.0       11      0       2     Altus         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 215          223  126.0       2.0     C      4  60.0       11      0       2     Altus         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 216          224  128.0       2.0     D      4  62.0       11      0       2     Altus         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 217          225  130.0       2.0     E      4  64.0       11      0       2     Altus         120.0             120.0           3/1                  12/4   none          none     none    none     none
# 218          226  132.0       2.0     F      4  65.0       12      0       2     Altus         132.0             132.0           3/1                  12/4   none          none     none    none     none
# 219          227  134.0       2.0     C      4  60.0       12      0       2     Altus         132.0             132.0           3/1                  12/4   none          none     none    none     none
# 220          228  136.0       2.0     D      4  62.0       12      0       2     Altus         132.0             132.0           3/1                  12/4   none          none     none    none     none
# 221          229  138.0       2.0     C      4  60.0       12      0       2     Altus         132.0             132.0           3/1                  12/4   none          none     none    none     none
# 222          230  140.0       4.0     F      4  65.0       12      0       2     Altus         132.0             132.0           3/1                  12/4   none          none     none    none     none
# 223          231  144.0      12.0     E      4  64.0       13      0       2     Altus         144.0             144.0           3/1                  12/4   none          none     none    none     none
# 224          232  156.0       8.0  rest   rest   NaN       14      0       2     Altus         156.0             156.0           2/1                   8/4   none          none     none    none     none
# 225          233  164.0       8.0     E      4  64.0       15      0       2     Altus         164.0             164.0           2/1                   8/4   none          none     none    none     none
# 226          234  172.0       8.0     D      4  62.0       16      0       2     Altus         172.0             172.0           2/1                   8/4   none          none     none    none     none
# 227          235  180.0       4.0     C      4  60.0       17      0       2     Altus         180.0             180.0           2/1                   8/4   none          none     none    none     none
# 228          236  184.0       4.0     A      3  57.0       17      0       2     Altus         180.0             180.0           2/1                   8/4   none          none     none    none     none
# 229          237  188.0       4.0     B      3  59.0       18      0       2     Altus         188.0             188.0           2/1                   8/4   none          none     none    none     none
# 230          238  192.0       6.0     E      4  64.0       18      0       2     Altus         188.0             188.0           2/1                   8/4   none          none     none   start     none
# 231          240  198.0       2.0     D      4  62.0       19      0       2     Altus         196.0             196.0           2/1                   8/4   none          none     none    none     none
# 232          241  200.0       4.0     D      4  62.0       19      0       2     Altus         196.0             196.0           2/1                   8/4   none          none     none    none     none
# 233          242  204.0       4.0     C      4  60.0       20      0       2     Altus         204.0             204.0           2/1                   8/4   none          none     none    none     none
# 234          243  208.0       4.0     A      3  57.0       20      0       2     Altus         204.0             204.0           2/1                   8/4   none          none     none    none     none
# 235          244  212.0       8.0     B      3  59.0       21      0       2     Altus         212.0             212.0           2/1                   8/4   none          none     none    none     none
# ...
# 523          538  308.0       4.0     F      3  53.0       33      0       4    Bassus         308.0             308.0           2/1                   8/4   none          none     none    none     none
# 524          539  312.0       4.0     D      3  50.0       33      0       4    Bassus         308.0             308.0           2/1                   8/4   none          none     none    none     none
# 525          540  316.0       8.0     E      3  52.0       34      0       4    Bassus         316.0             316.0           2/1                   8/4   none          none     none    none     none
# 526          541  324.0       4.0  rest   rest   NaN       35      0       4    Bassus         324.0             324.0           2/1                   8/4   none          none     none    none     none
# 527          542  328.0       8.0     D      3  50.0       35      0       4    Bassus         324.0             324.0           2/1                   8/4   none          none     none   start     none
# 528          544  336.0       4.0     C      3  48.0       36      0       4    Bassus         332.0             332.0           2/1                   8/4   none          none     none    none     none
# 529          545  340.0       4.0   B-1      2  46.0       37      0       4    Bassus         340.0             340.0           2/1                   8/4   none          none     none    none     none
# 530          546  344.0       4.0     G      2  43.0       37      0       4    Bassus         340.0             340.0           2/1                   8/4   none          none     none    none     none
# 531          547  348.0       4.0     A      2  45.0       38      0       4    Bassus         348.0             348.0           2/1                   8/4   none          none     none    none     none
# 532          548  352.0       8.0     D      3  50.0       38      0       4    Bassus         348.0             348.0           2/1                   8/4   none          none     none   start     none
# 533          550  360.0       4.0     C      3  48.0       39      0       4    Bassus         356.0             356.0           2/1                   8/4   none          none     none    none     none
# 534          551  364.0       4.0   B-1      2  46.0       40      0       4    Bassus         364.0             364.0           2/1                   8/4   none          none     none    none     none
# 535          552  368.0       4.0     G      2  43.0       40      0       4    Bassus         364.0             364.0           2/1                   8/4   none          none     none    none     none
# 536          553  372.0       8.0     A      2  45.0       41      0       4    Bassus         372.0             372.0           2/1                   8/4   none          none     none    none     none
# 537          554  380.0      12.0  rest   rest   NaN       42      0       4    Bassus         380.0             380.0           3/1                  12/4   none          none     none    none     none
# 538          555  392.0      12.0  rest   rest   NaN       43      0       4    Bassus         392.0             392.0           3/1                  12/4   none          none     none    none     none
# 539          556  404.0      12.0  rest   rest   NaN       44      0       4    Bassus         404.0             404.0           3/1                  12/4   none          none     none    none     none
# 540          557  416.0       4.0     A      3  57.0       45      0       4    Bassus         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 541          558  420.0       2.0     G      3  55.0       45      0       4    Bassus         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 542          559  422.0       4.0     F      3  53.0       45      0       4    Bassus         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 543          560  426.0       2.0     D      3  50.0       45      0       4    Bassus         416.0             416.0           3/1                  12/4   none          none     none    none     none
# 544          561  428.0       2.0     E      3  52.0       46      0       4    Bassus         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 545          562  430.0       2.0     A      3  57.0       46      0       4    Bassus         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 546          563  432.0       2.0     G      3  55.0       46      0       4    Bassus         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 547          564  434.0       4.0     F      3  53.0       46      0       4    Bassus         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 548          565  438.0       2.0     D      3  50.0       46      0       4    Bassus         428.0             428.0           3/1                  12/4   none          none     none    none     none
# 549          566  440.0       2.0     E      3  52.0       47      0       4    Bassus         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 550          567  442.0       2.0     A      3  57.0       47      0       4    Bassus         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 551          568  444.0       2.0     G      3  55.0       47      0       4    Bassus         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 552          569  446.0       2.0     F      3  53.0       47      0       4    Bassus         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 553          570  448.0       4.0     D      3  50.0       47      0       4    Bassus         440.0             440.0           3/1                  12/4   none          none     none    none     none
# 554          571  452.0       4.0     E      3  52.0       48      0       4    Bassus         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 555          572  456.0       4.0  rest   rest   NaN       48      0       4    Bassus         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 556          573  460.0       4.0     A      3  57.0       48      0       4    Bassus         452.0             452.0           3/1                  12/4   none          none     none    none     none
# 557          574  464.0       2.0     G      3  55.0       49      0       4    Bassus         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 558          575  466.0       2.0     E      3  52.0       49      0       4    Bassus         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 559          576  468.0       2.0     G      3  55.0       49      0       4    Bassus         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 560          577  470.0       2.0     A      3  57.0       49      0       4    Bassus         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 561          578  472.0       2.0     F      3  53.0       49      0       4    Bassus         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 562          579  474.0       2.0     A      3  57.0       49      0       4    Bassus         464.0             464.0           3/1                  12/4   none          none     none    none     none
# 563          580  476.0       2.0     G      3  55.0       50      0       4    Bassus         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 564          581  478.0       2.0     E      3  52.0       50      0       4    Bassus         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 565          582  480.0       2.0     G      3  55.0       50      0       4    Bassus         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 566          583  482.0       2.0     A      3  57.0       50      0       4    Bassus         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 567          584  484.0       4.0     F      3  53.0       50      0       4    Bassus         476.0             476.0           3/1                  12/4   none          none     none    none     none
# 568          585  488.0       2.0     E      3  52.0       51      0       4    Bassus         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 569          586  490.0       2.0     C      3  48.0       51      0       4    Bassus         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 570          587  492.0       2.0     D      3  50.0       51      0       4    Bassus         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 571          588  494.0       2.0     F      3  53.0       51      0       4    Bassus         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 572          589  496.0       4.0     E      3  52.0       51      0       4    Bassus         488.0             488.0           3/1                  12/4   none          none     none    none     none
# 573          590  500.0       4.0     A      2  45.0       52      0       4    Bassus         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 574          591  504.0       4.0  rest   rest   NaN       52      0       4    Bassus         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 575          592  508.0       4.0     D      3  50.0       52      0       4    Bassus         500.0             500.0           3/1                  12/4   none          none     none    none     none
# 576          593  512.0       2.0     C      3  48.0       53      0       4    Bassus         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 577          594  514.0       2.0     A      2  45.0       53      0       4    Bassus         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 578          595  516.0       2.0     C      3  48.0       53      0       4    Bassus         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 579          596  518.0       2.0     D      3  50.0       53      0       4    Bassus         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 580          597  520.0       2.0   B-1      2  46.0       53      0       4    Bassus         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 581          598  522.0       2.0     D      3  50.0       53      0       4    Bassus         512.0             512.0           3/1                  12/4   none          none     none    none     none
# 582          599  524.0       2.0     C      3  48.0       54      0       4    Bassus         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 583          600  526.0       2.0     A      2  45.0       54      0       4    Bassus         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 584          601  528.0       2.0     C      3  48.0       54      0       4    Bassus         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 585          602  530.0       2.0     D      3  50.0       54      0       4    Bassus         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 586          603  532.0       4.0   B-1      2  46.0       54      0       4    Bassus         524.0             524.0           3/1                  12/4   none          none     none    none     none
# 587          604  536.0       4.0     A      2  45.0       55      0       4    Bassus         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 588          605  540.0       4.0  rest   rest   NaN       55      0       4    Bassus         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 589          606  544.0       4.0     A      3  57.0       55      0       4    Bassus         536.0             536.0           3/1                  12/4   none          none     none    none     none
# 590          607  548.0       2.0     G      3  55.0       56      0       4    Bassus         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 591          608  550.0       2.0     E      3  52.0       56      0       4    Bassus         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 592          609  552.0       2.0     G      3  55.0       56      0       4    Bassus         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 593          610  554.0       2.0     A      3  57.0       56      0       4    Bassus         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 594          611  556.0       2.0     F      3  53.0       56      0       4    Bassus         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 595          612  558.0       2.0     A      3  57.0       56      0       4    Bassus         548.0             548.0           3/1                  12/4   none          none     none    none     none
# 596          613  560.0       2.0     G      3  55.0       57      0       4    Bassus         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 597          614  562.0       2.0     E      3  52.0       57      0       4    Bassus         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 598          615  564.0       2.0     G      3  55.0       57      0       4    Bassus         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 599          616  566.0       2.0     A      3  57.0       57      0       4    Bassus         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 600          617  568.0       4.0     F      3  53.0       57      0       4    Bassus         560.0             560.0           3/1                  12/4   none          none     none    none     none
# 601          618  572.0      12.0     E      3  52.0       58      0       4    Bassus         572.0             572.0           3/1                  12/4   none          none     none    none     none

# %% [markdown]
# ### 4. Pianorollendarstellung

# %% [markdown]
# Im folgenden Codefenster aktivieren Sie die Pianorollendarstellung.
#
# Dabei gibt es zwei Möglichkeiten:
# 1. Im Browser ("inline"): Dies erfordert in Abhängigkeit von der Datengröße viel Speicherplatz.
# 2. In einem externen Pop-Up-Fenster, d.h. in der Symbolleiste ihres Desktops taucht ein neues Icon auf, das Sie anklicken müssen: Hierzu muss zunächst der Befehal '%matplotlib' aktiviert werden - durch Löschung des #-Zeichens davor. Anschließend werden //alle// Grafiken extern dargestellt. Um sie wieder im Browser darzustellen, muss der Befehl '%matplotlib inline' eingegeben werden.
#
# TIPP: Öffnen Sie das externe Fenster (über das Icon in der Desktop-Symbolleiste unten) und navigieren Sie anschließend mit Ihrer Maus in der Grafik; über das Rädchen können Sie die horizontale Ausdehnung der Grafik verändern. Anschließend können Sie die gewählte Darstellung als Bilddatei (.png) abspeichern!

# %% [markdown]
# @ Egor: Bitte erläutere doch kurz die Parameter des folgenden Befehls!!

# %%
# %matplotlib

m_df = mp.parse.with_xml_file(file=xml_file, plot_pianoroll=False, plot_inline_ipynb=False)

#file: str, only file is manditory

#plot_pianoroll: bool = False,
#plot_inline_ipynb: bool=False,
#save_at: str = None,
#save_file_name: str = None,
#do_save: bool = False,
#x_axis_res=2,
#get_measure_onset:bool=False, 
#get_upbeat_info=False,
#filter_dict=None


# Definition der Variable für Pandas-Dataframe (m_df) sowie Beschreibung der verwendeten Parameter, 
# Angaben in der Regel mit True/False

# plot_pianoroll - Piano-Roll als Grafik zeichnen
# plot_inline_ipynb - Piano-Roll Als Grafik innnerhalb von Jupyter Notebook (True) oder als extra Fenster (False)
# save_at 
# save_file_name
# do_save
# x_axis_res - Auflösung der X-Achse als Teiler der Viertelnote (2=0.5 Viertelnote)
# get_measure_onset -
# Out:
# Using matplotlib backend: MacOSX
# /Users/chris/DocumentLocal/workspace/hfm/scripts_in_progress/xml_parser/music_xml_parser/core/xml_parser.py:884: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 0 in meau or '0' in meau:

# %%
# %matplotlib inline

# %% [markdown]
# Was können Sie auf der Pianorollen-Grafik erkennen?

# %% [markdown]
# ### 5. Auswahl von Stimmen bzw. Takten

# %% [markdown]
# Durch den folgenden Befehl können flexibel Stimmen und Takte für grafische Darstellungen oder Abfragen ausgewählt werden.
#
# Im folgenden Beispielen werden die ersten beiden Stimmen ('PartID':'1-2') und davon die Takte 2-5 ('Measure':'2-5') für eine Pianorollendarstellung ausgewählt. Die Darstellung erfolgt extern.

# %%
#%matplotlib
# %matplotlib inline
##Testing filter
#xml_file = 'PrJode_Jos1102_COM_1-5_MissaLasol_002_00137.xml'
# xml_file = 'https://analyse.hfm-weimar.de/database/03/MoWo_K279_COM_1-3_PianoSonat_003_00920.xml'


filter_dict_t = { 'Measure':'2-5', 'PartID':'1-2'}


m_df_2 = mp.parse.with_xml_file(file=xml_file,
                                plot_pianoroll=True,
                                plot_inline_ipynb=True,
                                filter_dict=filter_dict_t)
# Out:
# Using matplotlib backend: MacOSX
# Error in ploting piano roll
# Traceback (most recent call last):
#   File "/Users/chris/DocumentLocal/workspace/hfm/scripts_in_progress/xml_parser/music_xml_parser/core/plot.py", line 96, in plotting_wrapper_parts
#     n_df = df[['PartID', 'PartName']].to_numpy(dtype=str)
# TypeError: 'filter' object is not subscriptable
# /Users/chris/DocumentLocal/workspace/hfm/scripts_in_progress/xml_parser/music_xml_parser/core/xml_parser.py:884: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if 0 in meau or '0' in meau:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b30a8bef13fa> in <module>
#      18
#      19
# ---> 20 m_df2
#
# NameError: name 'm_df2' is not defined

# %%
m_df_2
# Out:
# Exception ignored on calling ctypes callback function: <function stop at 0x154d91940>
# Traceback (most recent call last):
#   File "/Users/chris/miniforge3/envs/hfm/lib/python3.9/site-packages/ipykernel/_eventloop_macos.py", line 107, in stop
#     _triggered.set()
#   File "/Users/chris/miniforge3/envs/hfm/lib/python3.9/threading.py", line 544, in set
#     self._cond.notify_all()
#   File "/Users/chris/miniforge3/envs/hfm/lib/python3.9/threading.py", line 381, in notify_all
#     self.notify(len(self._waiters))
#   File "/Users/chris/miniforge3/envs/hfm/lib/python3.9/threading.py", line 361, in notify
#     if not self._is_owned():
#   File "/Users/chris/miniforge3/envs/hfm/lib/python3.9/threading.py", line 274, in _is_owned
#     if self._lock.acquire(False):
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
# m_df_2

# Wenn Sie diesen Befehl aktivieren, 
# wird das Pandas-Dataframe des gewählten Ausschnitts als Tabelle dargestellt.

# %% [markdown]
# Nun der Vergleich mit der Altus-Stimme. Was lässt sich hieraus über die Art der Fortschreitung der beiden Stimmen sagen? Ist sie ähnlich oder unterschiedlich?

# %% [markdown]
# ### 6. Vertiefung

# %% [markdown]
# Vergleichen Sie die Pianorollendarstellung von verschiedenen Stimmen der Komposition. Was fällt auf?
#
# Generieren Sie Pianorollendarstellungen von anderen Kompositionen und machen Sie sich auf diese Weise mit dem Jupyter-Notebook vertraut.
